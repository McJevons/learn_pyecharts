# %% [markdown]
# ## 引入库，准备数据
# 在此借用新冠疫情部分数据
# 在武汉和黄石生活了十几年，还有很多亲戚也在那里，希望武汉加油！！黄石加油！！

# %%
from pyecharts.charts import Bar
from pyecharts.charts import Line
from pyecharts.charts import Map
from pyecharts import options as opts

x_date = [
    '2020-02-09', '2020-02-10', '2020-02-11', '2020-02-12', '2020-02-13',
    '2020-02-14', '2020-02-15', '2020-02-16', '2020-02-17', '2020-02-18'
]

y_huangshi = [760, 805, 835, 874, 911, 943, 980, 988, 988, 985]

y_ezhou = [639, 725, 790, 861, 1065, 1125, 1192, 1230, 1274, 1339]

# %% [markdown]
# ## 柱形图

# %%
bar=Bar()

bar.add_xaxis(x_date) # 添加x轴数据

bar.add_yaxis('黄石',y_huangshi) # 添加y轴数据

bar.render_notebook() # 显示图表
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="35ef70b28bdf4d60989a61bba9dab0d5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_35ef70b28bdf4d60989a61bba9dab0d5 = echarts.init(
#                     document.getElementById('35ef70b28bdf4d60989a61bba9dab0d5'), 'white', {renderer: 'canvas'});
#                 var option_35ef70b28bdf4d60989a61bba9dab0d5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u9ec4\u77f3",
#             "data": [
#                 760,
#                 805,
#                 835,
#                 874,
#                 911,
#                 943,
#                 980,
#                 988,
#                 988,
#                 985
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9ec4\u77f3"
#             ],
#             "selected": {
#                 "\u9ec4\u77f3": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2020-02-09",
#                 "2020-02-10",
#                 "2020-02-11",
#                 "2020-02-12",
#                 "2020-02-13",
#                 "2020-02-14",
#                 "2020-02-15",
#                 "2020-02-16",
#                 "2020-02-17",
#                 "2020-02-18"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_35ef70b28bdf4d60989a61bba9dab0d5.setOption(option_35ef70b28bdf4d60989a61bba9dab0d5);
#         });
#     </script>

# %%
# 同时显示多列数据
bar.add_yaxis('鄂州',y_ezhou) # 再添加一条y轴数据

bar.render_notebook() # 显示图表
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a0e7b393f6184e2fad2e5ff301647dde" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a0e7b393f6184e2fad2e5ff301647dde = echarts.init(
#                     document.getElementById('a0e7b393f6184e2fad2e5ff301647dde'), 'white', {renderer: 'canvas'});
#                 var option_a0e7b393f6184e2fad2e5ff301647dde = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u9ec4\u77f3",
#             "data": [
#                 760,
#                 805,
#                 835,
#                 874,
#                 911,
#                 943,
#                 980,
#                 988,
#                 988,
#                 985
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u9102\u5dde",
#             "data": [
#                 639,
#                 725,
#                 790,
#                 861,
#                 1065,
#                 1125,
#                 1192,
#                 1230,
#                 1274,
#                 1339
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9ec4\u77f3",
#                 "\u9102\u5dde"
#             ],
#             "selected": {
#                 "\u9ec4\u77f3": true,
#                 "\u9102\u5dde": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2020-02-09",
#                 "2020-02-10",
#                 "2020-02-11",
#                 "2020-02-12",
#                 "2020-02-13",
#                 "2020-02-14",
#                 "2020-02-15",
#                 "2020-02-16",
#                 "2020-02-17",
#                 "2020-02-18"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_a0e7b393f6184e2fad2e5ff301647dde.setOption(option_a0e7b393f6184e2fad2e5ff301647dde);
#         });
#     </script>

# %% [markdown]
# ## 折线图
# 与柱形图同为直角坐标系图表，因此添加数据方法基本相同

# %%
line=Line()

line.add_xaxis(x_date) # 添加x轴数据

line.add_yaxis('黄石',y_huangshi) # 添加y轴数据

line.add_yaxis('鄂州',y_ezhou) # 继续向y轴添加一列数据

line.render_notebook() # 显示图表
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c6771169feb8491f9317b9fa2f75e359" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c6771169feb8491f9317b9fa2f75e359 = echarts.init(
#                     document.getElementById('c6771169feb8491f9317b9fa2f75e359'), 'white', {renderer: 'canvas'});
#                 var option_c6771169feb8491f9317b9fa2f75e359 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u9ec4\u77f3",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2020-02-09",
#                     760
#                 ],
#                 [
#                     "2020-02-10",
#                     805
#                 ],
#                 [
#                     "2020-02-11",
#                     835
#                 ],
#                 [
#                     "2020-02-12",
#                     874
#                 ],
#                 [
#                     "2020-02-13",
#                     911
#                 ],
#                 [
#                     "2020-02-14",
#                     943
#                 ],
#                 [
#                     "2020-02-15",
#                     980
#                 ],
#                 [
#                     "2020-02-16",
#                     988
#                 ],
#                 [
#                     "2020-02-17",
#                     988
#                 ],
#                 [
#                     "2020-02-18",
#                     985
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u9102\u5dde",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2020-02-09",
#                     639
#                 ],
#                 [
#                     "2020-02-10",
#                     725
#                 ],
#                 [
#                     "2020-02-11",
#                     790
#                 ],
#                 [
#                     "2020-02-12",
#                     861
#                 ],
#                 [
#                     "2020-02-13",
#                     1065
#                 ],
#                 [
#                     "2020-02-14",
#                     1125
#                 ],
#                 [
#                     "2020-02-15",
#                     1192
#                 ],
#                 [
#                     "2020-02-16",
#                     1230
#                 ],
#                 [
#                     "2020-02-17",
#                     1274
#                 ],
#                 [
#                     "2020-02-18",
#                     1339
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9ec4\u77f3",
#                 "\u9102\u5dde"
#             ],
#             "selected": {
#                 "\u9ec4\u77f3": true,
#                 "\u9102\u5dde": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2020-02-09",
#                 "2020-02-10",
#                 "2020-02-11",
#                 "2020-02-12",
#                 "2020-02-13",
#                 "2020-02-14",
#                 "2020-02-15",
#                 "2020-02-16",
#                 "2020-02-17",
#                 "2020-02-18"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_c6771169feb8491f9317b9fa2f75e359.setOption(option_c6771169feb8491f9317b9fa2f75e359);
#         });
#     </script>

# %% [markdown]
# ## 层叠多图
# 将不同类型的图表叠加在一张图表内
# `A.overlap(B)`：将图表B叠加进图表A中

# %%
# 将折线图叠加到柱形图中
bar.overlap(line)

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8da0777c92f741d195cbc2a4521a9e15" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8da0777c92f741d195cbc2a4521a9e15 = echarts.init(
#                     document.getElementById('8da0777c92f741d195cbc2a4521a9e15'), 'white', {renderer: 'canvas'});
#                 var option_8da0777c92f741d195cbc2a4521a9e15 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u9ec4\u77f3",
#             "data": [
#                 760,
#                 805,
#                 835,
#                 874,
#                 911,
#                 943,
#                 980,
#                 988,
#                 988,
#                 985
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u9102\u5dde",
#             "data": [
#                 639,
#                 725,
#                 790,
#                 861,
#                 1065,
#                 1125,
#                 1192,
#                 1230,
#                 1274,
#                 1339
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u9ec4\u77f3",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2020-02-09",
#                     760
#                 ],
#                 [
#                     "2020-02-10",
#                     805
#                 ],
#                 [
#                     "2020-02-11",
#                     835
#                 ],
#                 [
#                     "2020-02-12",
#                     874
#                 ],
#                 [
#                     "2020-02-13",
#                     911
#                 ],
#                 [
#                     "2020-02-14",
#                     943
#                 ],
#                 [
#                     "2020-02-15",
#                     980
#                 ],
#                 [
#                     "2020-02-16",
#                     988
#                 ],
#                 [
#                     "2020-02-17",
#                     988
#                 ],
#                 [
#                     "2020-02-18",
#                     985
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u9102\u5dde",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2020-02-09",
#                     639
#                 ],
#                 [
#                     "2020-02-10",
#                     725
#                 ],
#                 [
#                     "2020-02-11",
#                     790
#                 ],
#                 [
#                     "2020-02-12",
#                     861
#                 ],
#                 [
#                     "2020-02-13",
#                     1065
#                 ],
#                 [
#                     "2020-02-14",
#                     1125
#                 ],
#                 [
#                     "2020-02-15",
#                     1192
#                 ],
#                 [
#                     "2020-02-16",
#                     1230
#                 ],
#                 [
#                     "2020-02-17",
#                     1274
#                 ],
#                 [
#                     "2020-02-18",
#                     1339
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9ec4\u77f3",
#                 "\u9102\u5dde",
#                 "\u9ec4\u77f3",
#                 "\u9102\u5dde"
#             ],
#             "selected": {
#                 "\u9ec4\u77f3": true,
#                 "\u9102\u5dde": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2020-02-09",
#                 "2020-02-10",
#                 "2020-02-11",
#                 "2020-02-12",
#                 "2020-02-13",
#                 "2020-02-14",
#                 "2020-02-15",
#                 "2020-02-16",
#                 "2020-02-17",
#                 "2020-02-18"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_8da0777c92f741d195cbc2a4521a9e15.setOption(option_8da0777c92f741d195cbc2a4521a9e15);
#         });
#     </script>

# %%
from pyecharts.charts import Bar
from pyecharts.charts import Line
from pyecharts import options as opts

x_date = [
    '2020-02-09', '2020-02-10', '2020-02-11', '2020-02-12', '2020-02-13',
    '2020-02-14', '2020-02-15', '2020-02-16', '2020-02-17', '2020-02-18'
]

y_huangshi = [760, 805, 835, 874, 911, 943, 980, 988, 988, 985]

y_ezhou = [639, 725, 790, 861, 1065, 1125, 1192, 1230, 1274, 1339]

# %%
bar=Bar()

# %%
bar=Bar()
bar.add_xaxis(x_date)
bar.add_yaxis('鄂州',y_ezhou)
bar.add_yaxis(
    series_name='黄石',
    yaxis_data=y_huangshi,
    color='blue',
    gap='10%',
    category_gap='30%',
    label_opts=opts.LabelOpts(
        is_show=False,
        color='red',
        font_size=20
        )
)
bar.set_global_opts(
    yaxis_opts=opts.AxisOpts(
        name='text',
        axislabel_opts=opts.LabelOpts(color='red')
    
    ))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4c84b29b78e74356a7151dc7e4b30748" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4c84b29b78e74356a7151dc7e4b30748 = echarts.init(
#                     document.getElementById('4c84b29b78e74356a7151dc7e4b30748'), 'white', {renderer: 'canvas'});
#                 var option_4c84b29b78e74356a7151dc7e4b30748 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "blue",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u9102\u5dde",
#             "data": [
#                 639,
#                 725,
#                 790,
#                 861,
#                 1065,
#                 1125,
#                 1192,
#                 1230,
#                 1274,
#                 1339
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u9ec4\u77f3",
#             "data": [
#                 760,
#                 805,
#                 835,
#                 874,
#                 911,
#                 943,
#                 980,
#                 988,
#                 988,
#                 985
#             ],
#             "barCategoryGap": "30%",
#             "barGap": "10%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "color": "red",
#                 "margin": 8,
#                 "fontSize": 20
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9102\u5dde",
#                 "\u9ec4\u77f3"
#             ],
#             "selected": {
#                 "\u9102\u5dde": true,
#                 "\u9ec4\u77f3": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2020-02-09",
#                 "2020-02-10",
#                 "2020-02-11",
#                 "2020-02-12",
#                 "2020-02-13",
#                 "2020-02-14",
#                 "2020-02-15",
#                 "2020-02-16",
#                 "2020-02-17",
#                 "2020-02-18"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "text",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "color": "red",
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_4c84b29b78e74356a7151dc7e4b30748.setOption(option_4c84b29b78e74356a7151dc7e4b30748);
#         });
#     </script>
